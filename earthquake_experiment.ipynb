# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing

raw_earthquake_data = pd.read_csv("earthquake_indonesia.csv", engine='python')
earthquake_csv
# Out:
#           NO   TANGGAL         WAKTU   LINTANG      BUJUR KEDALAMAN     Mag  \
# 0          1  01-01-09  01:26:04 UTC   3.73 LU  127.34 BT     67 Km  4.6 SR
# 1          2  01-01-09  03:45:00 UTC   6.84 LS  130.22 BT    103 Km  5.2 SR
# 2          3  01-01-09  05:27:08 UTC   1.45 LU  120.74 BT     10 Km  5.1 SR
# 3          4  01-01-09  08:42:09 UTC   1.52 LU  122.01 BT     10 Km  4.5 SR
# 4          5  01-01-09  08:57:01 UTC   8.44 LS  116.17 BT     91 Km  3.4 SR
# 5          6  01-01-09  10:35:35 UTC   1.41 LU     122 BT     34 Km    5 SR
# 6          7  01-01-09  12:36:57 UTC   9.37 LU  124.14 BT    529 Km  4.7 SR
# 7          8  01-01-09  13:02:11 UTC   7.17 LS  108.44 BT     10 Km  3.3 SR
# 8          9  01-01-09  13:23:41 UTC   0.65 LU  100.99 BT    127 Km  3.2 SR
# 9         10  01-01-09  15:49:54 UTC   4.32 LS  119.56 BT     10 Km  3.1 SR
# 10        11  01-01-09  16:57:53 UTC   4.41 LS  101.11 BT     21 Km  5.3 SR
# ...
